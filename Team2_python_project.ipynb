# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score
from sklearn.metrics import RocCurveDisplay
from sklearn import metrics

# %%
# reading the source file 
df = pd.read_csv("smoking.csv")
df.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0            1.0             1.0  ...        12.9
# 1              0.6            1.0             1.0  ...        12.7
# 2              0.8            1.0             1.0  ...        15.8
# 3              1.5            1.0             1.0  ...        14.7
# 4              1.0            1.0             1.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0     Y              0
# 1            1.0               0.6  22.0  19.0  18.0     Y              0
# 2            1.0               1.0  21.0  16.0  22.0     Y              0
# 3            1.0               1.0  19.0  26.0  18.0     Y              0
# 4            1.0               0.6  16.0  14.0  22.0     Y              0
#
#    tartar  smoking
# 0       Y        0
# 1       Y        0
# 2       N        1
# 3       Y        0
# 4       N        0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Data Dictionary
#
# - ID : index
# - gender
# - age : 5-years gap
# - height(cm)
# - weight(kg)
# - waist(cm) : Waist circumference length
# - eyesight(left)
# - eyesight(right)
# - hearing(left)
# - hearing(right)
# - systolic : Blood pressure
# - relaxation : Blood pressure
# - fasting blood sugar
# - Cholesterol : total
# - triglyceride
# - HDL : cholesterol type
# - LDL : cholesterol type
# - hemoglobin
# - Urine protein
# - serum creatinine
# - AST : glutamic oxaloacetic transaminase type
# - ALT : glutamic oxaloacetic transaminase type
# - Gtp : γ-GTP
# - oral : Oral Examination status
# - dental caries
# - tartar : tartar status
# - smoking : Target variable

# %%
# size of the dataset
df.shape
# Out:
# (55692, 27)

# %%
# checking the types of the variables 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55692 entries, 0 to 55691
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   55692 non-null  int64
#  1   gender               55692 non-null  object
#  2   age                  55692 non-null  int64
#  3   height(cm)           55692 non-null  int64
#  4   weight(kg)           55692 non-null  int64
#  5   waist(cm)            55692 non-null  float64
#  6   eyesight(left)       55692 non-null  float64
#  7   eyesight(right)      55692 non-null  float64
#  8   hearing(left)        55692 non-null  float64
#  9   hearing(right)       55692 non-null  float64
#  10  systolic             55692 non-null  float64
#  11  relaxation           55692 non-null  float64
#  12  fasting blood sugar  55692 non-null  float64
#  13  Cholesterol          55692 non-null  float64
#  14  triglyceride         55692 non-null  float64
#  15  HDL                  55692 non-null  float64
#  16  LDL                  55692 non-null  float64
#  17  hemoglobin           55692 non-null  float64
#  18  Urine protein        55692 non-null  float64
#  19  serum creatinine     55692 non-null  float64
#  20  AST                  55692 non-null  float64
#  21  ALT                  55692 non-null  float64
#  22  Gtp                  55692 non-null  float64
#  23  oral                 55692 non-null  object
#  24  dental caries        55692 non-null  int64
#  25  tartar               55692 non-null  object
#  26  smoking              55692 non-null  int64
# dtypes: float64(18), int64(6), object(3)
# memory usage: 11.5+ MB

# %%
# a quick overlook on how the data 
df.describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  55692.000000  55692.000000  55692.000000  55692.000000  55692.000000
# mean   27845.500000     44.182917    164.649321     65.864936     82.046418
# std    16077.039933     12.071418      9.194597     12.820306      9.274223
# min        0.000000     20.000000    130.000000     30.000000     51.000000
# 25%    13922.750000     40.000000    160.000000     55.000000     76.000000
# 50%    27845.500000     40.000000    165.000000     65.000000     82.000000
# 75%    41768.250000     55.000000    170.000000     75.000000     88.000000
# max    55691.000000     85.000000    190.000000    135.000000    129.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    55692.000000     55692.000000   55692.000000    55692.000000
# mean         1.012623         1.007443       1.025587        1.026144
# std          0.486873         0.485964       0.157902        0.159564
# min          0.100000         0.100000       1.000000        1.000000
# 25%          0.800000         0.800000       1.000000        1.000000
# 50%          1.000000         1.000000       1.000000        1.000000
# 75%          1.200000         1.200000       1.000000        1.000000
# max          9.900000         9.900000       2.000000        2.000000
#
#            systolic  ...           HDL           LDL    hemoglobin  \
# count  55692.000000  ...  55692.000000  55692.000000  55692.000000
# mean     121.494218  ...     57.290347    114.964501     14.622592
# std       13.675989  ...     14.738963     40.926476      1.564498
# min       71.000000  ...      4.000000      1.000000      4.900000
# 25%      112.000000  ...     47.000000     92.000000     13.600000
# 50%      120.000000  ...     55.000000    113.000000     14.800000
# 75%      130.000000  ...     66.000000    136.000000     15.800000
# max      240.000000  ...    618.000000   1860.000000     21.100000
#
#        Urine protein  serum creatinine           AST           ALT  \
# count   55692.000000      55692.000000  55692.000000  55692.000000
# mean        1.087212          0.885738     26.182935     27.036037
# std         0.404882          0.221524     19.355460     30.947853
# min         1.000000          0.100000      6.000000      1.000000
# 25%         1.000000          0.800000     19.000000     15.000000
# 50%         1.000000          0.900000     23.000000     21.000000
# 75%         1.000000          1.000000     28.000000     31.000000
# max         6.000000         11.600000   1311.000000   2914.000000
#
#                 Gtp  dental caries       smoking
# count  55692.000000   55692.000000  55692.000000
# mean      39.952201       0.213334      0.367288
# std       50.290539       0.409665      0.482070
# min        1.000000       0.000000      0.000000
# 25%       17.000000       0.000000      0.000000
# 50%       25.000000       0.000000      0.000000
# 75%       43.000000       0.000000      1.000000
# max      999.000000       1.000000      1.000000
#
# [8 rows x 24 columns]

# %%
# checking for NULL's
df.isnull().sum()
# Out:
# ID                     0
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %% [markdown]
# # Initial Data Analysis

# %%
# checking for data imbalance 
sns.countplot(df, x="smoking").set(title="Distribution of the target variable")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# [Text(0.5, 1.0, 'Distribution of the target variable')]

# %%
sns.displot(df["hearing(left)"])
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df["hearing(right)"])
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df["hearing(left)"].unique()
# Out:
# array([1., 2.])

# %%
# hearing, systolic, relaxation, fasting blood sugar level, cholesterol, triglyceride , smoking

sns.displot(df["Cholesterol"])
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# hearing, systolic, relaxation, fasting blood sugar level, cholesterol, triglyceride , smoking

sns.displot(df["systolic"])
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# hearing, systolic, relaxation, fasting blood sugar level, cholesterol, triglyceride , smoking

sns.displot(df["relaxation"])
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# hearing, systolic, relaxation, fasting blood sugar level, cholesterol, triglyceride , smoking

sns.displot(df["triglyceride"])
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(data = df, y = "triglyceride", x= "fasting blood sugar",hue = "gender",size= "smoking")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='fasting blood sugar', ylabel='triglyceride'>

# %%
sns.scatterplot(data = df, y = "Cholesterol", x= "fasting blood sugar",hue = "gender")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='fasting blood sugar', ylabel='Cholesterol'>

# %%
sns.boxplot(data = df, x ="gender" , y= "Cholesterol", hue="smoking")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='gender', ylabel='Cholesterol'>

# %%
sns.boxplot(data = df, x ="smoking" , y= "fasting blood sugar",hue="gender")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='smoking', ylabel='fasting blood sugar'>

# %%
sns.boxplot(data = df, x ="smoking" , y= "systolic",hue="gender")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='smoking', ylabel='systolic'>

# %%
sns.boxplot(data = df, x ="smoking" , y= "ALT")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='smoking', ylabel='ALT'>

# %%
# hearing, systolic, relaxation, fasting blood sugar level, cholesterol, triglyceride , smoking
sns.boxplot(data = df, x ="gender" , y= "relaxation",hue="smoking").set(title = "Relationship between smoking and relaxation")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# [Text(0.5, 1.0, 'Relationship between smoking and relaxation')]

# %%
sns.boxplot(data = df, x ="smoking" , y= "triglyceride",hue="gender")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='smoking', ylabel='triglyceride'>

# %%
sns.barplot(data = df, y = "Cholesterol", x= "hearing(left)",hue = "gender")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hearing(left)', ylabel='Cholesterol'>

# %%
sns.barplot(data = df, y = "hearing(right)", x= "smoking")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='smoking', ylabel='hearing(right)'>

# %%
sns.boxplot(data = df, x = "age",y ="height(cm)",hue="gender")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='age', ylabel='height(cm)'>

# %%
# LDL < 100 healthy heart
# HDL > 60 healthy heart
# data_male= df[df["gender"=="M"]]
# data_female= df[df["gender"=="F"]]
data_male = df[df["gender"]=="M"]
data_female = df[df["gender"]=="F"]
data_female
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0          0      F   40         155          60       81.3             1.2
# 1          1      F   40         160          60       81.0             0.8
# 4          4      F   40         155          60       86.0             1.0
# 8          9      F   50         150          60       85.0             0.7
# 13        14      F   40         155          45       59.0             1.5
# ...      ...    ...  ...         ...         ...        ...             ...
# 55681  55652      F   45         160          65       75.0             1.2
# 55686  55673      F   60         150          50       75.0             1.0
# 55687  55676      F   40         170          65       75.0             0.9
# 55688  55681      F   45         160          50       70.0             1.2
# 55689  55683      F   55         160          50       68.5             1.0
#
#        eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0                  1.0            1.0             1.0  ...        12.9
# 1                  0.6            1.0             1.0  ...        12.7
# 4                  1.0            1.0             1.0  ...        12.5
# 8                  0.8            1.0             1.0  ...        13.7
# 13                 1.2            1.0             1.0  ...        12.6
# ...                ...            ...             ...  ...         ...
# 55681              1.2            1.0             1.0  ...        12.6
# 55686              1.2            1.0             1.0  ...        12.6
# 55687              0.9            1.0             1.0  ...        12.3
# 55688              1.2            1.0             1.0  ...        14.0
# 55689              1.2            1.0             1.0  ...        12.4
#
#        Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0                1.0               0.7  18.0  19.0  27.0     Y              0
# 1                1.0               0.6  22.0  19.0  18.0     Y              0
# 4                1.0               0.6  16.0  14.0  22.0     Y              0
# 8                1.0               0.8  31.0  31.0  14.0     Y              0
# 13               1.0               0.7  13.0   9.0   9.0     Y              0
# ...              ...               ...   ...   ...   ...   ...            ...
# 55681            1.0               0.8  27.0  21.0  13.0     Y              0
# 55686            1.0               0.8  26.0  21.0  14.0     Y              0
# 55687            1.0               0.6  14.0   7.0  10.0     Y              1
# 55688            1.0               0.9  20.0  12.0  14.0     Y              0
# 55689            1.0               0.5  17.0  11.0  12.0     Y              0
#
#        tartar  smoking
# 0           Y        0
# 1           Y        0
# 4           N        0
# 8           N        0
# 13          N        0
# ...       ...      ...
# 55681       Y        0
# 55686       Y        0
# 55687       Y        0
# 55688       Y        0
# 55689       N        0
#
# [20291 rows x 27 columns]

# %%
sns.scatterplot(data = data_male, x = "HDL",y ="triglyceride",hue="gender")

# Your healthcare provider classifies high triglyceride levels as:

# Mild: 150-199 mg/dL.
# Moderate: 200-499 mg/dL.
# Severe: Greater than 500 mg/dL.
# What are risk factors for high triglycerides?
# Factors that may raise triglyceride levels include:

# Excessive alcohol use.
# Family history of high cholesterol.
# Liver disease or kidney disease.
# Medications, including diuretics, hormones, corticosteroids and beta blockers.
# Menopause.
# Obesity.
# Smoking.
# Thyroid disease.
# Unregulated diabetes.
# A diet high in sugar and simple carbohydrates.
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='HDL', ylabel='triglyceride'>

# %%
sns.displot(data_female["HDL"]) 
# https://my.clevelandclinic.org/health/articles/11920-cholesterol-numbers-what-do-they-mean
# https://my.clevelandclinic.org/health/articles/11117-triglycerides
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(data = data_female, x = "HDL",y ="triglyceride",hue="gender")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='HDL', ylabel='triglyceride'>

# %%
# summary=df.groupby(["gender","smoking"])["age","weight(kg)","height(cm)"]
# summary.plot(kind="box",figsize=(15,7)) 

# males tend to smoke in their early stage of life i.e around 20 years whereas women generally tend to start smoking most likely at the age of 30
sns.boxplot(data= df , x ="gender",y="age",hue= "smoking").set(title = "Relationship between age and smoking")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# [Text(0.5, 1.0, 'Relationship between age and smoking')]

# %%
sns.boxplot(data= df , x ="gender",y="triglyceride",hue= "smoking").set(title = "Relationship between triglyceride and smoking based on gender")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# [Text(0.5, 1.0, 'Relationship between triglyceride and smoking based on gender')]

# %%
sns.boxplot(data= df , x ="gender",y="weight(kg)",hue= "smoking").set(title = "Relationship between weight and smoking")
# we can say that weight is not a major concern if a person smokes
# generally we have a misconception that people who smoke tend to weigh less, but the obvservation does not prove our assumption.
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# [Text(0.5, 1.0, 'Relationship between weight and smoking')]

# %%
sns.boxplot(data= df , x ="gender",y="height(cm)",hue= "smoking")
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='gender', ylabel='height(cm)'>

# %%
df['smoking'].value_counts(normalize = True)
# Out:
# smoking
# 0    0.632712
# 1    0.367288
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df,x='smoking', palette = "husl").set(title = "Distribution of the Target variable before balancing")
plt.legend()
plt.show()
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from imblearn.over_sampling import SMOTENC 
from sklearn.model_selection import train_test_split
from collections import Counter

# %%
X = df.iloc[:,0:26]
X
y= df["smoking"]
y = pd.DataFrame(y,columns = ["smoking"])
y
# Out:
#        smoking
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ...        ...
# 55687        0
# 55688        0
# 55689        0
# 55690        0
# 55691        1
#
# [55692 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
y_train.value_counts()
# Out:
# smoking
# 0          24680
# 1          14304
# Name: count, dtype: int64

# %% [markdown]
# # Start of the balancing techniques

# %%
# train = pd.concat([X_train,y_train],axis=1)
# test = pd.concat([X_test,y_test],axis=1)
# test
X.dtypes
# Out:
# ID                       int64
# gender                  object
# age                      int64
# height(cm)               int64
# weight(kg)               int64
# waist(cm)              float64
# eyesight(left)         float64
# eyesight(right)        float64
# hearing(left)          float64
# hearing(right)         float64
# systolic               float64
# relaxation             float64
# fasting blood sugar    float64
# Cholesterol            float64
# triglyceride           float64
# HDL                    float64
# LDL                    float64
# hemoglobin             float64
# Urine protein          float64
# serum creatinine       float64
# AST                    float64
# ALT                    float64
# Gtp                    float64
# oral                    object
# dental caries            int64
# tartar                  object
# dtype: object

# %%
# balancing the data out
sm = SMOTENC(random_state=42,categorical_features=[1,23,25])
X_res, y_res = sm.fit_resample(X_train, y_train)

# %%
# percentage of values after balancing
y_res.value_counts(normalize = True)
# Out:
# smoking
# 0          0.5
# 1          0.5
# Name: proportion, dtype: float64

# %%
X_res.shape
# Out:
# (49360, 26)

# %%
sns.countplot(data=y_res,x='smoking', palette = "husl").set(title = "Distribution of the Target variable after balancing")
plt.legend()
plt.show()
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Anaconda\envs\Work\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Modelling

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import accuracy_score

# %%
# getting dummies for train 
X_res = pd.get_dummies(X_res)
X_res
X_res = X_res.iloc[:,1:26]

# %%
# getting dummies for test
X_test = pd.get_dummies(X_test)
X_test = X_test.iloc[:,1:26]

# %%
X_train = X_res
y_train = y_res

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (49360, 25)
# (49360, 1)

# %%
classifier = LogisticRegression()
model = classifier.fit(X_train,y_train)
y_pred = model.predict(X_test)
confusion = confusion_matrix(y_test, y_pred)
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Anaconda\envs\Work\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# printing the confusion matrix

disp = ConfusionMatrixDisplay(confusion)
disp.plot()

# %%
# confusion matrix 
TN = confusion[0,0]
TP = confusion[1,1]
FN = confusion[1,0]
FP = confusion[0,1]
# Evaluation Matrix 
Accuracy = (TP+TN)/(TP+TN+FP+FN)
Precision = TP/(TP+FP)
Recall = TP/(TP +FN)
print("The accuracy of the model is", Accuracy)
print("The Precision of the model is", Precision)
print("The Recall of the model is", Recall)
# Out:
# The accuracy of the model is 0.7141489107014604
# The Precision of the model is 0.5838926174496645
# The Recall of the model is 0.7779222890586897

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.68      0.75     10557
#            1       0.58      0.78      0.67      6151
#
#     accuracy                           0.71     16708
#    macro avg       0.71      0.73      0.71     16708
# weighted avg       0.75      0.71      0.72     16708

# %%
disp = RocCurveDisplay.from_estimator(model, X_test, y_test, alpha=0.8)

plt.show()

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
feature_names = X_train.columns
feature_names
# Out:
# Index(['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
#        'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
#        'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
#        'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
#        'ALT', 'Gtp', 'dental caries', 'gender_F', 'gender_M', 'oral_Y'],
#       dtype='object')

# %%
clf1 = DecisionTreeClassifier( random_state = 42)
model2  = clf1.fit(X_train, y_train)
# a = tree.plot_tree(clf,
#                    #use the feature names stored
#                    feature_names = feature_names,
#                    rounded = True,
#                    filled = True,
#                    fontsize=14)
# plt.show()

# %%
# prediction 
y_Pred = model2.predict(X_test)

# %%
# printing the confusion matrix
confusion = confusion_matrix(y_test, y_Pred)
disp = ConfusionMatrixDisplay(confusion)
disp.plot()

# %%
print(classification_report(y_test, y_Pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82     10557
#            1       0.69      0.71      0.70      6151
#
#     accuracy                           0.77     16708
#    macro avg       0.76      0.76      0.76     16708
# weighted avg       0.78      0.77      0.77     16708

# %%
accuracy_score(y_test, y_Pred)
# Out:
# 0.773342111563323

# %%
disp = RocCurveDisplay.from_estimator(model2, X_test, y_test, alpha=0.8)

plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf2=RandomForestClassifier(random_state= 42,min_samples_split=2,n_estimators = 500)
model3 =clf2.fit(X_train, y_train)
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# prediction 
y_Predict = model3.predict(X_test)

# %%
# printing the confusion matrix
confusion = confusion_matrix(y_test, y_Predict)
disp = ConfusionMatrixDisplay(confusion)
disp.plot()

# %%
print (model3.score(X_test,y_test))
# Out:
# 0.8193081158726359

# %%
print(classification_report(y_test, y_Predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85     10557
#            1       0.71      0.85      0.78      6151
#
#     accuracy                           0.82     16708
#    macro avg       0.81      0.83      0.81     16708
# weighted avg       0.83      0.82      0.82     16708

# %%
feature_importances = pd.DataFrame(model3.feature_importances_, index =X_train.columns,  columns=['importance']).sort_values('importance', ascending=False)

# %%
feature_importances
# Out:
#                      importance
# gender_F               0.113563
# gender_M               0.109303
# Gtp                    0.073042
# hemoglobin             0.070096
# height(cm)             0.060288
# triglyceride           0.051524
# serum creatinine       0.044171
# age                    0.041451
# waist(cm)              0.039580
# ALT                    0.039096
# LDL                    0.037931
# HDL                    0.037464
# Cholesterol            0.037175
# weight(kg)             0.036575
# fasting blood sugar    0.035977
# systolic               0.035685
# AST                    0.035163
# relaxation             0.034161
# eyesight(right)        0.027760
# eyesight(left)         0.027302
# dental caries          0.005436
# Urine protein          0.003984
# hearing(right)         0.001662
# hearing(left)          0.001611
# oral_Y                 0.000000

# %%
feature_importances.plot(kind="bar").set(title="Feature Importance Plot")
# Out:
# [Text(0.5, 1.0, 'Feature Importance Plot')]

# %%
disp = RocCurveDisplay.from_estimator(model3, X_test, y_test, alpha=0.8)

plt.show()

# %% [markdown]
# Random forest with feature selection

# %%
X_train1 = X_train[["gender_F","gender_M","Gtp","hemoglobin","height(cm)","triglyceride","serum creatinine","age","waist(cm)","ALT","LDL","HDL"]]
X_test1 = X_test[["gender_F","gender_M","Gtp","hemoglobin","height(cm)","triglyceride","serum creatinine","age","waist(cm)","ALT","LDL","HDL"]]

# %%
X_test1.shape
# Out:
# (16708, 12)

# %%
clf3=RandomForestClassifier(random_state= 42,min_samples_split=2,n_estimators = 500)
model4 =clf3.fit(X_train1, y_train)
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# prediction 
y_Predict1 = model4.predict(X_test1)

# %%
# printing the confusion matrix
confusion = confusion_matrix(y_test, y_Predict1)
disp = ConfusionMatrixDisplay(confusion)
disp.plot()

# %%
print (model4.score(X_test1,y_test))
# Out:
# 0.8181110845104141

# %%
print(classification_report(y_test, y_Predict1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85     10557
#            1       0.72      0.84      0.77      6151
#
#     accuracy                           0.82     16708
#    macro avg       0.81      0.82      0.81     16708
# weighted avg       0.83      0.82      0.82     16708

# %%
disp = RocCurveDisplay.from_estimator(model4, X_test1, y_test, alpha=0.8)

plt.show()

# %% [markdown]
# Building the model after scaling the values

# %%
print(X_train.select_dtypes(exclude = object).columns)
print(X_test.select_dtypes(exclude = object).columns)
# Out:
# Index(['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
#        'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
#        'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
#        'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
#        'ALT', 'Gtp', 'dental caries', 'gender_F', 'gender_M', 'oral_Y'],
#       dtype='object')
# Index(['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
#        'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
#        'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
#        'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
#        'ALT', 'Gtp', 'dental caries', 'gender_F', 'gender_M', 'oral_Y'],
#       dtype='object')

# %%
mm_scaler = MinMaxScaler()
scaling_columns = ['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
       'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
       'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
       'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
       'ALT', 'Gtp', 'dental caries', 'gender_F', 'gender_M', 'oral_Y']
mm_scaler.fit(X_train[scaling_columns])
X_train[scaling_columns] = mm_scaler.transform(X_train[scaling_columns])
X_test[scaling_columns] = mm_scaler.transform(X_test[scaling_columns])

# %%
X_test
# Out:
#             age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 33967  0.384615    0.454545        0.25   0.260756        0.091837
# 21956  0.538462    0.181818        0.10   0.383312        0.071429
# 15458  0.076923    0.636364        0.50   0.560626        0.091837
# 36215  0.384615    0.636364        0.40   0.404172        0.040816
# 8886   0.307692    0.545455        0.30   0.338983        0.112245
# ...         ...         ...         ...        ...             ...
# 6146   0.230769    0.727273        0.65   0.581486        0.081633
# 49172  0.307692    0.545455        0.40   0.521512        0.112245
# 40065  0.153846    0.727273        0.45   0.417210        0.112245
# 3063   0.384615    0.272727        0.20   0.404172        0.071429
# 45382  0.461538    0.363636        0.15   0.208605        0.010204
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 33967         0.040816            0.0             0.0  0.246914    0.150943
# 21956         0.040816            0.0             0.0  0.203704    0.283019
# 15458         0.112245            0.0             0.0  0.240741    0.283019
# 36215         0.030612            0.0             0.0  0.327160    0.396226
# 8886          0.112245            0.0             0.0  0.320988    0.311321
# ...                ...            ...             ...       ...         ...
# 6146          0.081633            0.0             0.0  0.327160    0.396226
# 49172         0.142857            0.0             0.0  0.216049    0.188679
# 40065         0.030612            0.0             0.0  0.475309    0.490566
# 3063          0.061224            0.0             0.0  0.203704    0.245283
# 45382         0.061224            0.0             0.0  0.265432    0.264151
#
#        ...  hemoglobin  Urine protein  serum creatinine       AST       ALT  \
# 33967  ...    0.395062            0.0          0.060870  0.007669  0.003090
# 21956  ...    0.561728            0.0          0.052174  0.013037  0.004463
# 15458  ...    0.722222            0.0          0.060870  0.057515  0.049777
# 36215  ...    0.617284            0.0          0.043478  0.015337  0.015105
# 8886   ...    0.709877            0.0          0.078261  0.025307  0.023344
# ...    ...         ...            ...               ...       ...       ...
# 6146   ...    0.703704            0.0          0.078261  0.028374  0.027120
# 49172  ...    0.660494            0.0          0.078261  0.036810  0.036389
# 40065  ...    0.691358            0.0          0.078261  0.020706  0.018538
# 3063   ...    0.487654            0.0          0.052174  0.008436  0.005493
# 45382  ...    0.493827            0.0          0.069565  0.014571  0.002403
#
#             Gtp  dental caries  gender_F  gender_M  oral_Y
# 33967  0.010020            0.0       1.0       0.0     0.0
# 21956  0.018036            1.0       1.0       0.0     0.0
# 15458  0.247495            1.0       0.0       1.0     0.0
# 36215  0.069138            0.0       0.0       1.0     0.0
# 8886   0.054108            0.0       0.0       1.0     0.0
# ...         ...            ...       ...       ...     ...
# 6146   0.042084            1.0       0.0       1.0     0.0
# 49172  0.072144            0.0       0.0       1.0     0.0
# 40065  0.024048            1.0       0.0       1.0     0.0
# 3063   0.020040            1.0       1.0       0.0     0.0
# 45382  0.014028            0.0       1.0       0.0     0.0
#
# [16708 rows x 25 columns]

# %%
rf = RandomForestClassifier(random_state =42)

rf.fit(X_train,y_train)

pred_tr = rf.predict_proba(X_train)[:,1]
pred_va = rf.predict_proba(X_test)[:,1]
y_Predict2 = rf.predict(X_test)

print(roc_auc_score(y_train,pred_tr))
print(roc_auc_score(y_test,pred_va))
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 1.0
# 0.9029332248081948

# %%
# printing the confusion matrix
confusion = confusion_matrix(y_test, y_Predict2)
disp = ConfusionMatrixDisplay(confusion)
disp.plot()

# %%
print(classification_report(y_test, y_Predict2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85     10557
#            1       0.71      0.84      0.77      6151
#
#     accuracy                           0.82     16708
#    macro avg       0.80      0.82      0.81     16708
# weighted avg       0.83      0.82      0.82     16708

# %%
# Is ROC AUC better than accuracy?
# In some cases (for uniformly distributed data), Accuracy may be more important than ROC AUC. 
# But in other cases (for extremely Imbalanced data), ROC AUC may be more important. Generally, 
# AUC is preferred over Accuracy as it is a much better indicator of model performance
rfc_disp = RocCurveDisplay.from_estimator(rf, X_test, y_test, alpha=0.8)
# rfc_disp.plot(ax=ax, alpha=0.8)
plt.show()

# %% [markdown]
# Implementing XGboost

# %%
from xgboost import XGBClassifier

# %%
# fit model no training data
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print(model)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82     10557
#            1       0.68      0.73      0.71      6151
#
#     accuracy                           0.78     16708
#    macro avg       0.76      0.77      0.76     16708
# weighted avg       0.78      0.78      0.78     16708

# %%
xgboost_disp = RocCurveDisplay.from_estimator(model, X_test, y_test, alpha=0.8)
# rfc_disp.plot(ax=ax, alpha=0.8)
plt.show()
# Out:
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# d:\Anaconda\envs\Work\Lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)

# %%
accuracy = accuracy_score(y_test, predictions)
accuracy
# Out:
# 0.7764543931050993

# %% [markdown]
# Anomaly detection

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
ss_scaler = StandardScaler()
scaling_columns = ['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
       'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
       'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
       'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
       'ALT', 'Gtp', 'dental caries', 'gender_F', 'gender_M', 'oral_Y']
ss_scaler.fit(X_train[scaling_columns])
X_train[scaling_columns] = ss_scaler.transform(X_train[scaling_columns])                                                                    
X_test[scaling_columns] = ss_scaler.transform(X_test[scaling_columns])

# %%
# feature selected columns
# X_train1 = X_train[["gender_F","gender_M","Gtp","hemoglobin","height(cm)","triglyceride","serum creatinine","age","waist(cm)","ALT","LDL","HDL"]]
# X_test1 = X_test[["gender_F","gender_M","Gtp","hemoglobin","height(cm)","triglyceride","serum creatinine","age","waist(cm)","ALT","LDL","HDL"]]

# %%
from sklearn.ensemble import IsolationForest

# %%
anomaly_detector = IsolationForest(contamination=0.05, random_state=42)  # Adjust the contamination parameter as needed
anomaly_detector.fit(X_train)
# Out:
# IsolationForest(contamination=0.05, random_state=42)

# %%
y_pred_anomalies = anomaly_detector.predict(X_test)
# Add a new column to your DataFrame indicating anomalies (1) and normal data (0)
df['anomaly'] = np.where(y_pred_anomalies == -1, 1, 0)

# %%
y_pred_anomalies
# Out:
# array([ 1,  1, -1, ...,  1,  1,  1])

# %%
train_anomalies = (y_train == -1).sum() / len(y_train)
threshold = train_anomalies  # Set the threshold based on the training data anomaly rate

# Create a binary array indicating anomalies (1) and normal data (0)
y_pred_anomalies_binary = (y_pred_anomalies == -1).astype(int)

# %%
# Model Evaluation
print("Anomaly Detection Performance:")
print("Threshold for anomalies:", threshold)
print("Accuracy:", accuracy_score(y_test, y_pred_anomalies_binary))
print("Precision:", precision_score(y_test, y_pred_anomalies_binary))
print("Recall:", recall_score(y_test, y_pred_anomalies_binary))
print("F1 Score:", f1_score(y_test, y_pred_anomalies_binary))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_anomalies_binary))
# Out:
# Anomaly Detection Performance:
# Threshold for anomalies: smoking    0.0
# dtype: float64
# Accuracy: 0.6113239166866172
# Precision: 0.3330087633885102
# Recall: 0.05560071533084052
# F1 Score: 0.09529116745611592
# Confusion Matrix:
# [[9872  685]
#  [5809  342]]
